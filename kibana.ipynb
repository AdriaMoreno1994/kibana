# %% [markdown]
# # T01: Visualització interactiva amb ElasticSearch Stack

# %% [markdown]
# ## Nivell 1
# ### Exercici 1
# Descarrega't Kibana i mostra algunes gràfiques utilitzant conjunts de dades d'Exemple.

# %% [markdown]
# First we download from elastic website the  elastic + kibana stack.After, we instal both packages.once all it's intalled we run elastic.bat and  kibana

# %%
from IPython.display import Image
Image(filename='image1.png')

# %%
Image(filename='image2.png')

# %% [markdown]
# once we are connected by localhost we can access to all the features.For the  first exercice, we load a sample data and  make and extract a few visualizations

# %% [markdown]
# Stock breakdown by category

# %%
Image(filename='image3.png')

# %% [markdown]
# Orders by country

# %%
Image(filename='Image4.png')

# %% [markdown]
# Daily comparison

# %%
Image(filename='comparison.png')

# %% [markdown]
# ## Nivell 2
# ### Exercici 1
# Implementa un dashboard que visualitzi interactivament les dades que triïs.

# %%
Image(filename='Image5.png')

# %% [markdown]
# ## Nivell 3
# ### Exercici 1
# Implementa un dashboard que generi gràfics utilitzant cadascun dels diferents tipus de gràfics que ofereix Kibana.

# %%
Image(filename='image6.png')

# %%
Image(filename='image7.png')

# %%
Image(filename='image8.png')
